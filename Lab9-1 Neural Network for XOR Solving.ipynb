# %% [markdown]
# ## Neural Network for XOR
#
#
# tensorflow는 어떻게 XOR 문제를 해결하는지 에 대해서 학습

# %%
import tensorflow as tf
import numpy as np

x_data = [[0, 0],
          [0, 1],
          [1, 0],
          [1, 1]]
y_data = [[0],
          [1],
          [1],
          [0]]

x_data = np.array(x_data, dtype = np.float32)
y_data = np.array(y_data, dtype = np.float32)

#XOR은 값이 1  또는 0 이기 때문에 logistic regression을 사용하여 간단하게 해결 할 수 있다.
#복습: Logistic Regression 기존의 Linear Regression을 사용 하게 되면 threshold가 일정하게 설정이 되지 않기 때문에 classification이 정상적으로 이루어 지지 않는다
#그렇기 때문에 Logistic을 이용하요 0~1 사이의 값을 내보내도록 적용 시킨다.

X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)
#값이 2개가 들어오고 1개가 나가므로 placeholder 는 [2, 1]이 되고 ,bias = out의 수와 항상 동일
W = tf.Variable(tf.random_normal([2, 1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = tf.sigmoid(tf.matmul(X, W)+ b)

cost = -tf.reduce_mean( Y * tf.log(hypothesis) + (1 - Y) * tf.log(1 - hypothesis))
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

predicted = tf.cast(hypothesis > 0.5, dtype = tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(10001):
        sess.run(train,feed_dict={X: x_data, Y: y_data})
        if step % 100 == 0:
            print(step,sess.run(cost, feed_dict={X: x_data, Y: y_data}), sess.run(W))
            
            h, c, a = sess.run([hypothesis, predicted, accuracy], feed_dict={X: x_data, Y: y_data})
            print("\nHypothesis: ",h, "\nCorrect: ",c, "\nAccuracy: ",a)
# Out:
# 0 0.8216419 [[-0.77671564]
#  [ 0.5167    ]]
#
# Hypothesis:  [[0.30782047]
#  [0.42711574]
#  [0.16980015]
#  [0.2553376 ]]
# Correct:  [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Accuracy:  0.5
# 100 0.70238197 [[-0.22252889]
#  [ 0.48932654]]
#
# Hypothesis:  [[0.45555282]
#  [0.57714576]
#  [0.401123  ]
#  [0.5221202 ]]
# Correct:  [[0.]
#  [1.]
#  [0.]
#  [1.]]
# Accuracy:  0.5
# 200 0.69602156 [[-0.09623268]
#  [ 0.28553802]]
#
# Hypothesis:  [[0.4718395 ]
#  [0.543087  ]
#  [0.44794086]
#  [0.51912665]]
# Correct:  [[0.]
#  [1.]
#  [0.]
#  [1.]]
# Accuracy:  0.5
# 300 0.6940721 [[-0.03807917]
#  [ 0.16609782]]
#
# Hypothesis:  [[0.4810194 ]
#  [0.52251947]
#  [0.47152135]
#  [0.513012  ]]
# Correct:  [[0.]
#  [1.]
#  [0.]
#  [1.]]
# Accuracy:  0.5
# 400 0.69345796 [[-0.01133939]
#  [ 0.09777039]]
#
# Hypothesis:  [[0.48718643]
#  [0.5116241 ]
#  [0.48435387]
#  [0.50879043]]
# Correct:  [[0.]
#  [1.]
#  [0.]
#  [1.]]
# Accuracy:  0.5
# 500 0.6932571 [[2.4728084e-05]
#  [5.8318175e-02]]
# ...

# %% [markdown]
# >Logistic regression을 이용하여 XOR을 해결 할수 있는가?
#
# 정확도가 0.5밖에 안되는 것을 볼수 있다. 즉 XOR 을 해결 할 수가 없다.
#
# ### 해결책은 Neural Net

# %%
#W 2개의 input , 2개의 output
W1 = tf.Variable(tf.random_normal([2, 2]), name = 'weight1')
#bias output 2개
b1 =  tf.Variable(tf.random_normal([2]), name='bias1')
layer1 = tf.sigmoid(tf.matmul(X, W1) + b1)
#주의점 : Weight의 크기를 잘 설정 해야한다 

W2 = tf.Variable(tf.random_normal([2, 1]), name = 'weight2')
b2 =  tf.Variable(tf.random_normal([1]), name='bias2')
#layer1 의 입력후 sigmoid 로 가설값 설정
hypothesis = tf.sigmoid(tf.matmul(layer1, W2) + b2)


# X -> (sigmoid) -> Layer1 -> (sigmoid) -> Y 형태

# %%
import tensorflow as tf
import numpy as np

x_data = [[0, 0],
          [0, 1],
          [1, 0],
          [1, 1]]
y_data = [[0],
          [1],
          [1],
          [0]]

x_data = np.array(x_data, dtype = np.float32)
y_data = np.array(y_data, dtype = np.float32)

#W 2개의 input , 2개의 output
W1 = tf.Variable(tf.random_normal([2, 2]), name = 'weight1')
#bias output 2개
b1 =  tf.Variable(tf.random_normal([2]), name='bias1')
layer1 = tf.sigmoid(tf.matmul(X, W1) + b1)
#주의점 : Weight의 크기를 잘 설정 해야한다 

W2 = tf.Variable(tf.random_normal([2, 1]), name = 'weight2')
b2 =  tf.Variable(tf.random_normal([1]), name='bias2')
#layer1 의 입력후 sigmoid 로 가설값 설정
hypothesis = tf.sigmoid(tf.matmul(layer1, W2) + b2)

cost = -tf.reduce_mean( Y * tf.log(hypothesis) + (1 - Y) * tf.log(1 - hypothesis))
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

predicted = tf.cast(hypothesis > 0.5, dtype = tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(10001):
        sess.run(train,feed_dict={X: x_data, Y: y_data})
        if step % 100 == 0:
            print(step,sess.run(cost, feed_dict={X: x_data, Y: y_data}), sess.run(W))
            
            h, c, a = sess.run([hypothesis, predicted, accuracy], feed_dict={X: x_data, Y: y_data})
            print("\nHypothesis: ",h, "\nCorrect: ",c, "\nAccuracy: ",a)
# Out:
# 0 0.81463075 [[-0.7561326 ]
#  [-0.18919806]]
#
# Hypothesis:  [[0.746752  ]
#  [0.7352322 ]
#  [0.72002536]
#  [0.7132369 ]]
# Correct:  [[1.]
#  [1.]
#  [1.]
#  [1.]]
# Accuracy:  0.5
# 100 0.6942861 [[-0.7561326 ]
#  [-0.18919806]]
#
# Hypothesis:  [[0.5290663 ]
#  [0.5249458 ]
#  [0.47540513]
#  [0.4706251 ]]
# Correct:  [[1.]
#  [1.]
#  [0.]
#  [0.]]
# Accuracy:  0.5
# 200 0.69227123 [[-0.7561326 ]
#  [-0.18919806]]
#
# Hypothesis:  [[0.5237698 ]
#  [0.5285854 ]
#  [0.4715539 ]
#  [0.47162983]]
# Correct:  [[1.]
#  [1.]
#  [0.]
#  [0.]]
# Accuracy:  0.5
# 300 0.69048196 [[-0.7561326 ]
#  [-0.18919806]]
#
# Hypothesis:  [[0.51955533]
#  [0.5328748 ]
#  [0.46795264]
#  [0.47272217]]
# Correct:  [[1.]
#  [1.]
#  [0.]
#  [0.]]
# Accuracy:  0.5
# 400 0.6887537 [[-0.7561326 ]
#  [-0.18919806]]
#
# Hypothesis:  [[0.5158159 ]
#  [0.5375034 ]
#  [0.46410865]
#  [0.47337574]]
# Correct:  [[1.]
#  [1.]
#  [0.]
#  [0.]]
# Accuracy:  0.5
# 500 0.68693745 [[-0.7561326 ]
#  [-0.18919806]]
#
# ...

# %% [markdown]
# 정확도가 1.0가 되는것을 확인 할 수가 있다.
# 이때 가설값은 1일때는 큰값 0일때는 작은 값은 값으로 설정이 되는 것을 확인 할 수 있다.
# 예측 값또한 거의 일치한다.
#
# 결론 : Neural Net을 활용하면 XOR 문제도 해결 할 수 있다.

# %% [markdown]
# ### 그러면 wide 한 Output을 가진 XOR 문제는 어떻게 되는가?

# %%
#W 2개의 input , 10개의 output
W1 = tf.Variable(tf.random_normal([2, 10]), name = 'weight1')
#bias output 10개
b1 =  tf.Variable(tf.random_normal([10]), name='bias1')
layer1 = tf.sigmoid(tf.matmul(X, W1) + b1)

W2 = tf.Variable(tf.random_normal([10, 1]), name = 'weight2')
b2 =  tf.Variable(tf.random_normal([1]), name='bias2')
hypothesis = tf.sigmoid(tf.matmul(layer1, W2) + b2)

# %% [markdown]
# 위 코드로 변경해서 실행 할 경우 hypothesis의 값은 조금더 0 1 1 0 인 Y값과 일치 해지는 것을 확인 할 수 있다.
# 즉 모델이 학습이 더 정확하게 잘된다라는 뜻이다.

# %% [markdown]
# ### Layer 를 'Deep'하게 추가하여 XOR 문제를 해결할 NN 모델은?

# %% [markdown]
# layer 1 -> layer2 .... ->layerN  추가 할 시에는 앞에서 wide 하게 학습 시킨 거보다 훨씬 더 실제 값과 비슷하게 나오는 것을 확인 할수 있다
# 즉 학습의 정확도가 올라가 학습이 잘된다.
